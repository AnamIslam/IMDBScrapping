# %%
import pandas as pd
import numpy as np
imdb_all_movie = pd.read_csv("all_movie_rating_with_des_1951_2020_cleaned.csv", sep = ',')
#print(imdb_all_movie)

# %%
type(imdb_all_movie)
# Out:
# pandas.core.frame.DataFrame

# %%
imdb_all_movie.head()
# Out:
#    Unnamed: 0                         Movies  \
# 0           0            Alice in Wonderland
# 1           1           Strangers on a Train
# 2           2       A Streetcar Named Desire
# 3           3  The Day the Earth Stood Still
# 4           4              The African Queen
#
#                                             Director  Year Certificate  IMDB  \
# 0  Clyde Geronimi,Wilfred Jackson,Hamilton Luske,...  1951           G   7.4
# 1                                   Alfred Hitchcock  1951          PG   7.9
# 2                                         Elia Kazan  1951          PG   8.0
# 3                                        Robert Wise  1951           G   7.7
# 4                                        John Huston  1951          PG   7.7
#
#    Metascore   Votes    Gross  Runtime                       Genre  \
# 0       68.0  129118       -1       75  Animation,Adventure,Family
# 1       88.0  123423  7630000      101    Crime,Film-Noir,Thriller
# ...

# %%
imdb_all_movie= imdb_all_movie.rename(columns={'Unnamed: 0':'Index'})
imdb_all_movie.head()
# Out:
#    Index                         Movies  \
# 0      0            Alice in Wonderland
# 1      1           Strangers on a Train
# 2      2       A Streetcar Named Desire
# 3      3  The Day the Earth Stood Still
# 4      4              The African Queen
#
#                                             Director  Year Certificate  IMDB  \
# 0  Clyde Geronimi,Wilfred Jackson,Hamilton Luske,...  1951           G   7.4
# 1                                   Alfred Hitchcock  1951          PG   7.9
# 2                                         Elia Kazan  1951          PG   8.0
# 3                                        Robert Wise  1951           G   7.7
# 4                                        John Huston  1951          PG   7.7
#
#    Metascore   Votes    Gross  Runtime                       Genre  \
# 0       68.0  129118       -1       75  Animation,Adventure,Family
# 1       88.0  123423  7630000      101    Crime,Film-Noir,Thriller
# ...

# %%
temp_movie_imdbRating = imdb_all_movie[imdb_all_movie.IMDB>9]
temp_movie_imdbRating
# Out:
#        Index                    Movies                Director  Year  \
# 3044    3044               Maya Bazaar    Kadiri Venkata Reddy  1957
# 9620    9620          Jibon Theke Neya            Zahir Raihan  1970
# 10500  10500             The Godfather    Francis Ford Coppola  1972
# 12011  12011            Hababam Sinifi           Ertem Egilmez  1975
# 21500  21500  The Shawshank Redemption          Frank Darabont  1994
# 21752  21752         Aguner Poroshmoni           Humayun Ahmed  1994
# 30366  30366           Love on a Leash                Fen Tian  2011
# 32696  32696               Mirror Game  Amitabh Reza Chowdhury  2016
#
#          Certificate  IMDB  Metascore    Votes      Gross  Runtime  \
# 3044       Not Rated   9.1       -1.1     4081         -1      192
# 9620   Not Certified   9.3       -1.1     1862         -1      150
# 10500              R   9.2      100.0  1622312  134966411      175
# 12011  Not Certified   9.3       -1.1    37327         -1       87
# ...

# %%
temp_movie_votes = imdb_all_movie[imdb_all_movie.Votes>2000000]
temp_movie_votes
# Out:
#        Index                    Movies           Director  Year Certificate  \
# 21500  21500  The Shawshank Redemption     Frank Darabont  1994           R
# 28500  28500           The Dark Knight  Christopher Nolan  2008       PG-13
# 29500  29500                 Inception  Christopher Nolan  2010       PG-13
#
#        IMDB  Metascore    Votes      Gross  Runtime                    Genre  \
# 21500   9.3       80.0  2345628   28341469      142                    Drama
# 28500   9.0       84.0  2305674  534858444      152       Action,Crime,Drama
# 29500   8.8       74.0  2069460  292576195      148  Action,Adventure,Sci-Fi
#
#                                              Description
# 21500  Two imprisoned men bond over a number of years...
# 28500  When the menace known as the Joker wreaks havo...
# 29500  A thief who steals corporate secrets through t...

# %%
temp_movie_minrating = imdb_all_movie[imdb_all_movie.IMDB<1.5]
temp_movie_minrating
# Out:
#        Index                           Movies                 Director  Year  \
# 7252    7252              Fun in Balloon Land  Joseph M. Sonneborn Jr.  1965
# 10675  10675    Santa and the Ice Cream Bunny            Richard Winer  1972
# 13098  13098               The Butterfly Ball             Tony Klinger  1977
# 15395  15395                  Night of Horror          Tony Malanowski  1981
# 16929  16929          Venni vidi e m'arrapaoh        Vincenzo Salviani  1984
# 18882  18882                          Ricky 1          William T. Naud  1988
# 20750  20750                           Ax 'Em            Michael Mfume  1992
# 31789  31789  Kirk Cameron's Saving Christmas             Darren Doane  2014
# 32384  32384                     Potato Salad       Michael David Pate  2015
# 32865  32865                         Smolensk            Antoni Krauze  2016
# 33082  33082                             Reis          Hüdaverdi Yavuz  2017
# ...

# %%
imdb_all_movie['Certificate'].unique()
# Out:
# array(['G', 'PG', 'Approved', 'Passed', 'TV-PG', 'Not Rated',
#        'Not Certified', 'Unrated', 'TV-G', 'Open', 'TV-14', 'PG-13', 'GP',
#        'R', 'M/PG', 'TV-Y7', 'M', 'TV-MA', 'X', 'TV-13', 'TV-Y7-FV',
#        'NC-17', 'AO', 'TV-Y', 'MA-17'], dtype=object)

# %%
temp_movie_cert = imdb_all_movie[imdb_all_movie.Certificate == 'X']
temp_movie_cert
# Out:
#        Index                                Movies           Director  Year  \
# 6785    6785                        Kiss Me Quick!    Peter Perry Jr.  1964
# 7990    7990  The Notorious Daughter of Fanny Hill    Peter Perry Jr.  1966
# 8064    8064                 I Am Curious (Yellow)      Vilgot Sjöman  1967
# 8228    8228                        I Am What I Am        Tinto Brass  1967
# 8581    8581                                Vixen!         Russ Meyer  1968
# ...      ...                                   ...                ...   ...
# 14915  14915                       High Test Girls  Erwin C. Dietrich  1980
# 17307  17307                              Tenement    Roberta Findlay  1985
# 17327  17327                           Future-Kill    Ronald W. Moore  1985
# 17730  17730                    Devil in the Flesh   Marco Bellocchio  1986
# 18020  18020                           Angel Heart        Alan Parker  1987
#
# ...

# %%
temp_movie_Title = imdb_all_movie[imdb_all_movie.Movies == 'The Secret Life of Walter Mitty']
temp_movie_Title
# Out:
#        Index                           Movies     Director  Year Certificate  \
# 31031  31031  The Secret Life of Walter Mitty  Ben Stiller  2013          PG
#
#        IMDB  Metascore   Votes     Gross  Runtime                 Genre  \
# 31031   7.3       54.0  293681  58236838      114  Comedy,Drama,Fantasy
#
#                                              Description
# 31031  When both he and a colleague are about to lose...
